# %% [markdown]
# * 1 Constrained optimization using trust-constr
# * 2 Constraint-free optimization using SLSQP
# * 3 Constraint-free optimization using optax

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# %alias_magic t timeit
# %load_ext memory_profiler

# %%
import os

# %%
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# %%
# import jax
# jax.config.update('jax_platform_name', 'cpu')
# jax.config.update("jax_enable_x64", False)
# import jax.numpy as jnp

# %%
import demes
import scipy
import pickle
import demesdraw
import sparse

import numpy as np
import matplotlib.pyplot as plt

import sys

from momi3.Params import Params
from momi3.MOMI import Momi

from momi3.optimizers import optax_for_momi

# %%
import jax
jax.devices()
# Out:
# [StreamExecutorGpuDevice(id=0, process_index=0, slice_index=0)]

# %%
# Load demes graph
demo = demes.load(f"timing_tests_yaml/5_pop_2_admix.yaml")

# %%
sampled_demes = demo.metadata['sampled_demes']
sample_sizes = 5 * [6]

# %%
# Construct momi
momi = Momi(demo, sampled_demes=sampled_demes, sample_sizes=sample_sizes, jitted=True)

# %%
# Simulate a short strain
jsfs = momi.simulate_chromosome(
    sequence_length=1e7,
    recombination_rate=1e-8,
    mutation_rate=1e-8,
    low_memory=False,
    seed=108
)

# %%
# Construct a Params object
params = Params(momi)

# %%
params.set_train('eta_1', True)
params.set_train('eta_7', True)
params.set_train('eta_8', True)
params.set_train('eta_5', True)
params.set_train('eta_6', True)

params.set_train('tau_1', True)
params.set_train('tau_4', True)
params.set_train('tau_7', True)

params.set_train('pi_0', True)
params.set_train('pi_1', True)

# %%
true_parameters = params.theta_train_dict()

# %%
# We will infer greens
params.tubes(show_values=True, show_letters=False, log_time=True,
             tau_keys=['tau_1', 'tau_4', 'tau_7'])

# %%
# %%time
momi.negative_loglik_with_gradient(params, jsfs)
# Out:
# CPU times: user 41 ms, sys: 7.13 ms, total: 48.1 ms
# Wall time: 30.6 ms
# (56521.94921875,
#  {'eta_1': 0.033254530280828476,
#   'tau_7': -0.11727027595043182,
#   'eta_6': 0.010233603417873383,
#   'eta_5': 0.07330276072025299,
#   'eta_8': 0.0009561654878780246,
#   'eta_7': 0.3874337673187256,
#   'pi_0': 4215.1123046875,
#   'tau_4': -0.07367650419473648,
#   'pi_1': 3720.086669921875,
#   'tau_1': -0.09113740921020508})

# %%
initial_dict = params.theta_train_dict()
train_keys = tuple(initial_dict)
theta_train_0 = np.array(list(initial_dict.values()))

# %%
# We'd like to minimize -\ell(theta_train; data)
def fun(theta_train, train_keys=train_keys):
    theta_train_dict = {}
    for key, val in zip(train_keys, theta_train):
        theta_train_dict[key] = float(val)
    val, grad = momi.negative_loglik_with_gradient(
        params, jsfs, theta_train_dict=theta_train_dict
    )
    grad = np.array(list(grad[key] for key in train_keys))
    return val, grad

# %%
# Evaluate the negative loglik value at theta_train_0 
val, grad = fun(theta_train_0)

print(f"Negative log likelihood: {float(val):.2f}")

print("="*10)

for key, d in zip(train_keys, theta_train_0):
    print(f"Value of {key}: {d:2f}")

print("="*10)
    
for key, d in zip(train_keys, grad):
    print(f"Derivative of {key}: {d:2f}")
# Out:
# /mnt/turbo/eneswork/jthlab/momi3/src/momi3/math_functions.py:14: UserWarning: Explicitly requested dtype float requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   x = jnp.array(x, dtype='float')
# Negative log likelihood: 56521.95
# ==========
# Value of eta_1: 13900.000000
# Value of eta_5: 2300.000000
# Value of eta_6: 10855.080952
# Value of eta_7: 650.000000
# Value of eta_8: 65834.770011
# Value of pi_0: 0.100000
# Value of pi_1: 0.100000
# Value of tau_1: 1000.000000
# Value of tau_4: 5000.000000
# Value of tau_7: 19275.862069
# ==========
# Derivative of eta_1: 0.033255
# Derivative of eta_5: 0.073303
# Derivative of eta_6: 0.010234
# Derivative of eta_7: 0.387434
# Derivative of eta_8: 0.000956
# Derivative of pi_0: 4215.113770
# Derivative of pi_1: 3720.081299
# Derivative of tau_1: -0.091137
# Derivative of tau_4: -0.073676
# Derivative of tau_7: -0.117270

# %% [markdown]
# # 1 Constrained Optimization

# %%
# You can add linear constraints easiliy

# Suppose you want CEU CHB divergence to be less than 1000 gen
params.add_linear_constraint('tau_1<=1000')

# %%
# Suppose you want neanderthal -> OOA proportion to be twice to,e larger than YRI -> Nea

# Below will throm an error Constraints should hold when you are assigning them
# params.add_linear_constraint('2*pi_0<=pi_1')

params.set('pi_0', 0.05)
params.add_linear_constraint('2*pi_0<=pi_1')

# %%
# Optimizer spesifications:
method = "trust-constr"
optimizer_options = dict(initial_tr_radius=1e-7, verbose=3)

# momi model constraints:
LinearConstraints = params._linear_constraints_for_scipy()

# %%
# Running the scipy optimizer
with jax.debug_nans(True):
    res = scipy.optimize.minimize(
        fun=fun,
        x0=theta_train_0,
        jac=True,
        constraints=LinearConstraints,
        method=method,
        options=optimizer_options,
    )
# Out:
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  | penalty  |barrier param|CG stop|
# |-------|-------|-------|-------------|----------|----------|----------|----------|-------------|-------|
# |   1   |   1   |   0   | +5.6522e+04 | 1.00e-07 | 1.70e+03 | 1.00e-01 | 1.00e+00 |  1.00e-01   |   0   |
# |   2   |   2   |   1   | +5.6522e+04 | 2.00e-07 | 1.70e+03 | 1.00e-01 | 1.00e+00 |  1.00e-01   |   2   |
# |   3   |   3   |   2   | +5.6522e+04 | 4.00e-07 | 1.70e+03 | 1.00e-01 | 1.00e+00 |  1.00e-01   |   2   |
# |   4   |   4   |   3   | +5.6522e+04 | 2.80e-06 | 1.70e+03 | 1.00e-01 | 1.00e+00 |  1.00e-01   |   2   |
# |   5   |   5   |   4   | +5.6522e+04 | 1.96e-05 | 1.70e+03 | 1.00e-01 | 1.00e+00 |  1.00e-01   |   2   |
# |   6   |   6   |   5   | +5.6522e+04 | 1.37e-04 | 1.70e+03 | 1.00e-01 | 1.00e+00 |  1.00e-01   |   2   |
-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  146  |  147  | 1028  | +5.5795e+04 | 5.91e+03 | 4.14e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  147  |  148  | 1038  | +5.5786e+04 | 7.10e+03 | 5.52e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   1   |
# |  148  |  149  | 1046  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  149  |  150  | 1054  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  150  |  151  | 1062  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  151  |  152  | 1070  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  152  |  153  | 1078  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  153  |  154  | 1086  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  154  |  155  | 1094  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  155  |  156  | 1102  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  156  |  157  | 1110  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  157  |  158  | 1118  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  158  |  159  | 1126  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  159  |  160  | 1134  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  160  |  161  | 1142  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  161  |  162  | 1150  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  162  |  163  | 1157  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  163  |  164  | 1165  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  164  |  165  | 1173  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  165  |  166  | 1181  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  166  |  167  | 1189  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  167  |  168  | 1197  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  168  |  169  | 1204  | +5.5786e+04 | 7.10e+03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  169  |  171  | 1208  | +5.5786e+04 | 7.10e+02 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  170  |  173  | 1213  | +5.5786e+04 | 7.10e+01 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  171  |  175  | 1218  | +5.5786e+04 | 7.10e+00 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  172  |  177  | 1223  | +5.5786e+04 | 7.10e-01 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  173  |  179  | 1228  | +5.5786e+04 | 7.10e-02 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  174  |  181  | 1233  | +5.5786e+04 | 7.10e-03 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  175  |  183  | 1237  | +5.5786e+04 | 7.10e-04 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |  176  |  184  | 1239  | +5.5786e+04 | 7.10e-04 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  177  |  185  | 1241  | +5.5786e+04 | 7.10e-04 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  178  |  186  | 1243  | +5.5786e+04 | 7.10e-05 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  179  |  187  | 1244  | +5.5786e+04 | 7.10e-06 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  180  |  188  | 1245  | +5.5786e+04 | 7.10e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  181  |  190  | 1246  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  182  |  191  | 1247  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  183  |  192  | 1248  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  184  |  193  | 1249  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  185  |  194  | 1250  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  186  |  195  | 1251  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  187  |  196  | 1252  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  188  |  197  | 1253  | +5.5786e+04 | 7.10e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  189  |  199  | 1254  | +5.5786e+04 | 7.10e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   2   |
# |  190  |  200  | 1254  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   0   |
# |  191  |  201  | 1255  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   2   |
# |  192  |  202  | 1256  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   2   |
# |  193  |  203  | 1257  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   2   |
# |  194  |  204  | 1257  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  8.00e-04   |   0   |
# |  195  |  205  | 1258  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  8.00e-04   |   2   |
# |  196  |  207  | 1259  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  8.00e-04   |   2   |
# |  197  |  208  | 1259  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.60e-04   |   0   |
# |  198  |  209  | 1260  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.60e-04   |   2   |
# |  199  |  210  | 1261  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.60e-04   |   2   |
# |  200  |  211  | 1261  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  3.20e-05   |   0   |
# |  201  |  213  | 1262  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  3.20e-05   |   2   |
# |  202  |  214  | 1263  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  3.20e-05   |   2   |
# |  203  |  215  | 1263  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  6.40e-06   |   0   |
# |  204  |  216  | 1264  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  6.40e-06   |   2   |
# |  205  |  217  | 1265  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  6.40e-06   |   2   |
# |  206  |  218  | 1265  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.28e-06   |   0   |
# |  207  |  219  | 1266  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.28e-06   |   2   |
# |  208  |  221  | 1267  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.28e-06   |   2   |
# |  209  |  222  | 1267  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.56e-07   |   0   |
# |  210  |  223  | 1268  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.56e-07   |   2   |
# |  211  |  225  | 1269  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.56e-07   |   2   |
# |  212  |  226  | 1269  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  5.12e-08   |   0   |
# |  213  |  227  | 1270  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  5.12e-08   |   2   |
# |  214  |  229  | 1271  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  5.12e-08   |   2   |
# |  215  |  230  | 1271  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.02e-08   |   0   |
# |  216  |  231  | 1272  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.02e-08   |   2   |
# |  217  |  233  | 1273  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  1.02e-08   |   2   |
# |  218  |  234  | 1273  | +5.5786e+04 | 1.00e-07 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.05e-09   |   0   |
# |  219  |  235  | 1274  | +5.5786e+04 | 1.00e-08 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.05e-09   |   2   |
# |  220  |  236  | 1275  | +5.5786e+04 | 1.00e-09 | 3.92e-02 | 0.00e+00 | 1.00e+00 |  2.05e-09   |   2   |
#
# `xtol` termination condition is satisfied.
# Number of iterations: 220, function evaluations: 236, CG iterations: 1275, optimality: 3.92e-02, constraint violation: 0.00e+00, execution time:  4.3 s.

# %%
theta_train_hat = res.x
theta_train_hat = dict(zip(train_keys, theta_train_hat))
for key, d in theta_train_hat.items():
    print(f"\hat{{{key}}}: {d:2f}")
# Out:
# \hat{eta_1}: 11031.241977
# \hat{eta_5}: 2764.924032
# \hat{eta_6}: 10132.300977
# \hat{eta_7}: 202.036059
# \hat{eta_8}: 65995.761302
# \hat{pi_0}: 0.022417
# \hat{pi_1}: 0.071906
# \hat{tau_1}: 1000.000000
# \hat{tau_4}: 5546.855396
# \hat{tau_7}: 23052.196357

# %%
params.set_optimization_results(theta_train_hat)

# %%
# We will infer greens
params.tubes(show_values=True, show_letters=False, log_time=True,
             tau_keys=['tau_1', 'tau_4', 'tau_7'])

# %%
# Get godombe
std_dev = momi.GIM_uncert(params, jsfs)

# %%
from momi3.utils import halfsigmoid
color_intensity_function = lambda x: halfsigmoid(x, scale=1e-8)

# %%
color_intensity_function(1e-8)
# Out:
# 0.4621171572600098

# %%
# You can visulize their standard devs

params.tubes(
    show_values=True, show_letters=False, log_time=True,
     tau_keys=['tau_1', 'tau_4', 'tau_7'],
    USER_DICT=std_dev,
    color_intensity_function=color_intensity_function
)

plt.title("Params colored by their Variance\n(Redder the value higher the Variance)");

# %% [markdown]
# # 2 Constraint Free Optimization
# This relies on parameter transformation

# %%
# reset the params
params = momi._default_params

# %%
params.set_train('eta_1', True)
params.set_train('eta_7', True)
params.set_train('eta_8', True)
params.set_train('eta_5', True)
params.set_train('eta_6', True)

params.set_train('tau_1', True)
params.set_train('tau_4', True)
params.set_train('tau_7', True)

params.set_train('pi_0', True)
params.set_train('pi_1', True)

# %%
initial_dict = params.theta_train_dict(transformed=True)
train_keys = tuple(initial_dict)
theta_train_0 = np.array(list(initial_dict.values()))

# %%
# We'd like to minimize -\ell(theta_train; data)
def fun(theta_train, train_keys=train_keys):
    theta_train_dict = {}
    for key, val in zip(train_keys, theta_train):
        theta_train_dict[key] = float(val)
    val, grad = momi.negative_loglik_with_gradient(
        params, jsfs, theta_train_dict=theta_train_dict, transformed=True
    )
    grad = np.array(list(grad[key] for key in train_keys))
    return val, grad

# %%
# Evaluate the negative loglik value at theta_train_0 
val, grad = fun(theta_train_0)

print(f"Negative log likelihood: {float(val):.2f}")

print("="*10)

for key, d in zip(train_keys, theta_train_0):
    print(f"Value of {key}: {d:2f}")

print("="*10)
    
for key, d in zip(train_keys, grad):
    print(f"Derivative of {key}: {d:2f}")
# Out:
# Negative log likelihood: 56521.95
# ==========
# Value of softplus(eta_1): 13900.000000
# Value of softplus(eta_5): 2300.000000
# Value of softplus(eta_6): 10855.080952
# Value of softplus(eta_7): 650.000000
# Value of softplus(eta_8): 65834.770011
# Value of logit(pi_0): -2.197225
# Value of logit(pi_1): -2.197225
# Value of log(tau_1-tau_0): 6.907755
# Value of log(tau_2-tau_1): 5.486370
# Value of log(tau_4-tau_3): 7.974841
# Value of log(tau_5-tau_4): 8.583885
# Value of log(tau_7-tau_6): 7.634804
# ==========
# Derivative of softplus(eta_1): 0.033254
# Derivative of softplus(eta_5): 0.073303
# Derivative of softplus(eta_6): 0.010234
# Derivative of softplus(eta_7): 0.387435
# Derivative of softplus(eta_8): 0.000956
# Derivative of logit(pi_0): 379.360016
# Derivative of logit(pi_1): 334.807770
# Derivative of log(tau_1-tau_0): 637.975342
# Derivative of log(tau_2-tau_1): 175.992691
# Derivative of log(tau_4-tau_3): 23.734962
# Derivative of log(tau_5-tau_4): 437.428589
# Derivative of log(tau_7-tau_6): -242.628403

# %%
# Force events to be at least exp(3) generations apart

res = scipy.optimize.minimize(
    fun=fun,
    x0=theta_train_0,
    jac=True,
    method="SLSQP",
    bounds=7 * [[None, None]] + 5*[[3., None]]
)

# %%
theta_train_hat = res.x
theta_train_hat = dict(zip(train_keys, theta_train_hat))
for key, d in theta_train_hat.items():
    print(f"\hat{{{key}}}: {d:2f}")
# Out:
# \hat{softplus(eta_1)}: 13894.145809
# \hat{softplus(eta_5)}: 2227.538055
# \hat{softplus(eta_6)}: 10846.133712
# \hat{softplus(eta_7)}: 171.755256
# \hat{softplus(eta_8)}: 65833.661599
# \hat{logit(pi_0)}: -3.587622
# \hat{logit(pi_1)}: -2.523199
# \hat{log(tau_1-tau_0)}: 6.751608
# \hat{log(tau_2-tau_1)}: 4.784977
# \hat{log(tau_4-tau_3)}: 8.431170
# \hat{log(tau_5-tau_4)}: 3.128162
# \hat{log(tau_7-tau_6)}: 8.566452

# %%
# This function automatically detects if a transformed theta_hat is given and applies the inverse of it
params.set_optimization_results(theta_train_hat)

# %%
params.tubes(show_values=True, show_letters=False, log_time=True,
             tau_keys=['tau_1', 'tau_4', 'tau_7'])

# %% [markdown]
# # 3 Constraint Free OPTAX

# %%
import jax.numpy as jnp
import optax

# %%
transformed = False
theta_train_dict = params.theta_train_dict(transformed)

# %%
theta_train_dict
# Out:
# {'eta_1': 13894.145809207417,
#  'eta_5': 2227.5380554260064,
#  'eta_6': 10846.133712448485,
#  'eta_7': 171.75525616768414,
#  'eta_8': 65833.66159892273,
#  'pi_0': 0.026919349295757764,
#  'pi_1': 0.07424777756400437,
#  'tau_1': 855.4332680777406,
#  'tau_4': 6680.970143550934,
#  'tau_7': 22459.358962635655}

# %%
# Set different learning rate for each eta, pi, tau
lr_eta = 1.
lr_pi = 0.001
lr_tau = 0.1

lr_vec = jnp.array(5 * [lr_eta] + 2 * [lr_pi] + 3 * [lr_tau])

# %%
optimizer = optax.adabelief(learning_rate=lr_vec, b1=0.3, b2=0.1)

# %%
theta_train_dict, opt_state, history = optax_for_momi(
    optimizer,
    momi,
    params,
    jsfs,
    niter=100,
    transformed=False,
    theta_train_dict=theta_train_dict,
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# /mnt/turbo/eneswork/jthlab/momi3/src/momi3/math_functions.py:14: UserWarning: Explicitly requested dtype float requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   x = jnp.array(x, dtype='float')

# %%
plt.plot(history['LLs'])
plt.title('learning curve')
# Out:
# Text(0.5, 1.0, 'learning curve')
