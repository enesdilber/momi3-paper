# %%
import numpy as np
def f(x):
    a = 1+np.sin(x)
    b = (2*x-3*np.pi)**2
    return a/b

# %%
a = 3*np.pi/2

# %%
2775.5571022616236/np.pi
# Out:
# 883.4872653175094

# %%
f(a+1e-10)
# Out:
# 2775.5571022616236
